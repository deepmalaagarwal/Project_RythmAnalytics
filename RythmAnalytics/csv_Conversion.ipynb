# %% [markdown]
# ### CSV Clean-Up Code
#
#
# -----

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "DataSets/albums.csv"

# Read Purchasing File and store into Pandas data frame
albums_data = pd.read_csv(file_to_load)

#Get an idea for what the data looks like 
albums_data.head()
# Out:
#    id  artist_id                           album_title        genre  \
# 0   1       1767    Call me Cat Moneyless That Doggies         Folk
# 1   2      23548                             Down Mare        Metal
# 2   3      17822                    Embarrassed Hungry       Latino
# 3   4      19565  Standard Immediate Engineer Slovakia          Pop
# 4   5      24941              Decent Distance Georgian  Black Metal
#
#    year_of_pub  num_of_tracks  num_of_sales  rolling_stone_critic  mtv_critic  \
# 0         2006             11        905193                   4.0         1.5
# 1         2014              7        969122                   3.0         4.0
# 2         2000             11        522095                   2.5         1.0
# 3         2017              4        610116                   1.5         2.0
# 4         2010              8        151111                   4.5         2.5
#
#    music_maniac_critic
# 0                  3.0
# 1                  5.0
# 2                  2.0
# 3                  4.0
# 4                  1.0

# %%
albums_data['album_title'] = albums_data['album_title'].apply(lambda x: ''.join([" " if ord(i) < 32 or ord(i) > 126 else i for i in x]))
albums_data.head(500)
# Out:
#       id  artist_id                            album_title        genre  \
# 0      1       1767     Call me Cat Moneyless That Doggies         Folk
# 1      2      23548                              Down Mare        Metal
# 2      3      17822                     Embarrassed Hungry       Latino
# 3      4      19565   Standard Immediate Engineer Slovakia          Pop
# 4      5      24941               Decent Distance Georgian  Black Metal
# ..   ...        ...                                    ...          ...
# 495  496       9109  Moves Permit Immediate They Were Star  Heavy Metal
# 496  497      28786                      American Boy Audi       Techno
# 497  498       5455                    Candy Elisa My Love        Dance
# 498  499      35529                     Magenta Successful   Holy Metal
# 499  500      45232                  Inconcepibile Turkish        K-Pop
#
#      year_of_pub  num_of_tracks  num_of_sales  rolling_stone_critic  \
# 0           2006             11        905193                   4.0
# 1           2014              7        969122                   3.0
# 2           2000             11        522095                   2.5
# 3           2017              4        610116                   1.5
# 4           2010              8        151111                   4.5
# ..           ...            ...           ...                   ...
# 495         2011             14        313496                   1.0
# 496         2000              7        133894                   5.0
# 497         2012              3        348313                   2.0
# 498         2008             13        509935                   3.5
# 499         2012              7        916307                   3.5
#
#      mtv_critic  music_maniac_critic
# 0           1.5                  3.0
# 1           4.0                  5.0
# 2           1.0                  2.0
# 3           2.0                  4.0
# 4           2.5                  1.0
# ..          ...                  ...
# 495         3.5                  4.0
# 496         1.5                  4.0
# 497         2.5                  4.0
# 498         3.5                  3.5
# 499         0.5                  3.0
#
# [500 rows x 10 columns]

# %%
albums_data.to_csv('file2.csv', index=False)

# %% [markdown]
# Improt Next CSV

# %%
# File to Load (Remember to Change These)
file_to_load2 = "DataSets/billboard_lyrics.csv"

# Read Purchasing File and store into Pandas data frame
billboard_lyrics_data = pd.read_csv(file_to_load2, encoding = "ISO-8859-1")

#Get an idea for what the data looks like 
billboard_lyrics_data.head(500)
# Out:
#      Rank                                         Song  \
# 0       1                                  wooly bully
# 1       2     i cant help myself sugar pie honey bunch
# 2       3                   i cant get no satisfaction
# 3       4                          you were on my mind
# 4       5                 youve lost that lovin feelin
# ..    ...                                          ...
# 495    96                                     laughing
# 496    97  my whole world ended the moment you left me
# 497    98                                    soul deep
# 498    99                          hooked on a feeling
# 499   100                           sweet cream ladies
#
#                             Artist  Year  \
# 0    sam the sham and the pharaohs  1965
# 1                        four tops  1965
# 2               the rolling stones  1965
# 3                          we five  1965
# 4           the righteous brothers  1965
# ..                             ...   ...
# 495                  the guess who  1969
# 496                   david ruffin  1969
# 497                   the box tops  1969
# 498                      bj thomas  1969
# 499                   the box tops  1969
#
#                                                 Lyrics  Source
# 0    sam the sham miscellaneous wooly bully wooly b...     3.0
# 1     sugar pie honey bunch you know that i love yo...     1.0
# 2                                                          1.0
# 3     when i woke up this morning you were on my mi...     1.0
# 4     you never close your eyes anymore when i kiss...     1.0
# ..                                                 ...     ...
# 495  i should laugh but i cry because your love has...     3.0
# 496   last week my life had meaning it was beautifu...     1.0
# 497   darlin i dont know much i know i love you so ...     1.0
# 498   i cant stop this feelin deep inside of me gir...     1.0
# 499  sweet cream ladies forward march the world owe...     3.0
#
# [500 rows x 6 columns]

# %%
billboard_lyrics_data.to_csv('cleaned_billboard_lyrics.csv', index=False)
